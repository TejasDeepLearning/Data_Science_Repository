# %% [markdown]
# # Visualising Earnings Based On College Majors
#
# In this project, we will focus on aggregating values in series's and visualising them, seeing what we can infer from those visusalisations and answer some questions based on what we see.
#
# We'll be working with a dataset on the job outcomes of students who graduated from college between 2010 and 2012. The original data on job outcomes was released by American Community Survey, which conducts surveys and aggregates the data. FiveThirtyEight cleaned the dataset and released it on their Github repo.
#
# Each row in the dataset represents a different major in college and contains information on gender diversity, employment rates, median salaries, and more. Here are some of the columns in the dataset:
#
# * Rank - Rank by median earnings (the dataset is ordered by this column).
# * Major_code - Major code.
# * Major - Major description.
# * Major_category - Category of major.
# * Total - Total number of people with major.
# * Sample_size - Sample size (unweighted) of full-time.
# * Men - Male graduates.
# * Women - Female graduates.
# * ShareWomen - Women as share of total.
# * Employed - Number employed.
# * Median - Median salary of full-time, year-round workers.
# * Low_wage_jobs - Number in low-wage service jobs.
# * Full_time - Number employed 35 hours or more.
# * Part_time - Number employed less than 35 hours.

# %% [markdown]
# Let's start by importing the libraries required for our procedure.

# %%
import pandas as pd
import matplotlib.pyplot as plt

# %% [markdown]
# We read the data from a csv file and turn it into a dataframe, then check the values of the first row.

# %%
recent_grads = pd.read_csv('recent-grads.csv')
recent_grads.iloc[0]
# Out:
# Rank                                        1
# Major_code                               2419
# Major                   PETROLEUM ENGINEERING
# Total                                    2339
# Men                                      2057
# Women                                     282
# Major_category                    Engineering
# ShareWomen                           0.120564
# Sample_size                                36
# Employed                                 1976
# Full_time                                1849
# Part_time                                 270
# Full_time_year_round                     1207
# Unemployed                                 37
# Unemployment_rate                   0.0183805
# Median                                 110000
# P25th                                   95000
# P75th                                  125000
# College_jobs                             1534
# Non_college_jobs                          364
# ...

# %% [markdown]
# We print the first and last few values of our dataset to get a better understanding of the data we're working with.

# %%
recent_grads.head()
# Out:
#    Rank  Major_code                                      Major    Total  \
# 0     1        2419                      PETROLEUM ENGINEERING   2339.0
# 1     2        2416             MINING AND MINERAL ENGINEERING    756.0
# 2     3        2415                  METALLURGICAL ENGINEERING    856.0
# 3     4        2417  NAVAL ARCHITECTURE AND MARINE ENGINEERING   1258.0
# 4     5        2405                       CHEMICAL ENGINEERING  32260.0
#
#        Men    Women Major_category  ShareWomen  Sample_size  Employed  \
# 0   2057.0    282.0    Engineering    0.120564           36      1976
# 1    679.0     77.0    Engineering    0.101852            7       640
# 2    725.0    131.0    Engineering    0.153037            3       648
# 3   1123.0    135.0    Engineering    0.107313           16       758
# 4  21239.0  11021.0    Engineering    0.341631          289     25694
#
#        ...        Part_time  Full_time_year_round  Unemployed  \
# ...

# %%
recent_grads.tail()
# Out:
#      Rank  Major_code                   Major   Total     Men   Women  \
# 168   169        3609                 ZOOLOGY  8409.0  3050.0  5359.0
# 169   170        5201  EDUCATIONAL PSYCHOLOGY  2854.0   522.0  2332.0
# 170   171        5202     CLINICAL PSYCHOLOGY  2838.0   568.0  2270.0
# 171   172        5203   COUNSELING PSYCHOLOGY  4626.0   931.0  3695.0
# 172   173        3501         LIBRARY SCIENCE  1098.0   134.0   964.0
#
#                Major_category  ShareWomen  Sample_size  Employed  \
# 168    Biology & Life Science    0.637293           47      6259
# 169  Psychology & Social Work    0.817099            7      2125
# 170  Psychology & Social Work    0.799859           13      2101
# 171  Psychology & Social Work    0.798746           21      3777
# 172                 Education    0.877960            2       742
#
#          ...        Part_time  Full_time_year_round  Unemployed  \
# 168      ...             2190                  3602         304
# ...

# %% [markdown]
# We use the `describe()` method to look at some of the information of the data.

# %%
recent_grads.describe()
# Out:
#              Rank   Major_code          Total            Men          Women  \
# count  173.000000   173.000000     172.000000     172.000000     172.000000
# mean    87.000000  3879.815029   39370.081395   16723.406977   22646.674419
# std     50.084928  1687.753140   63483.491009   28122.433474   41057.330740
# min      1.000000  1100.000000     124.000000     119.000000       0.000000
# 25%     44.000000  2403.000000    4549.750000    2177.500000    1778.250000
# 50%     87.000000  3608.000000   15104.000000    5434.000000    8386.500000
# 75%    130.000000  5503.000000   38909.750000   14631.000000   22553.750000
# max    173.000000  6403.000000  393735.000000  173809.000000  307087.000000
#
#        ShareWomen  Sample_size       Employed      Full_time      Part_time  \
# count  172.000000   173.000000     173.000000     173.000000     173.000000
# mean     0.522223   356.080925   31192.763006   26029.306358    8832.398844
# ...

# %% [markdown]
# We see that some rows have missing values. We'll drop those values for now using the `dataframe.dropna()` method.

# %%
recent_grads.shape
# Out:
# (173, 21)

# %%
raw_data_count = 173 # num of rows before dropping null values
recent_grads = recent_grads.dropna()

# %%
recent_grads.shape
# Out:
# (172, 21)

# %%
cleaned_data_count = 172 # num of rows after dropping null values

# %% [markdown]
# Let's create some scatterplots for analysing relationships between different variables in our dataset.

# %%
recent_grads.plot(x='Sample_size', y='Median', kind='scatter',
                  figsize=(10, 6))

# %%
recent_grads.plot(x='Sample_size', y='Unemployment_rate', 
                  kind='scatter',
                  figsize=(10, 6))

# %%
recent_grads.plot(x='Full_time', y='Median', kind='scatter',
                  figsize=(10, 6))

# %%
recent_grads.plot(x='ShareWomen', y='Unemployment_rate', 
                  kind='scatter',
                  figsize=(10, 6))

# %%
recent_grads.plot(x='Men', y='Median', kind='scatter',
                  figsize=(10, 6))

# %%
recent_grads.plot(x='Women', y='Median', kind='scatter',
                  figsize=(10, 6))

# %% [markdown]
# From this we can infer that:
#
# 1. Students belonging to more popular majors don't really make more money than the rest of their colleagues.
# 2. Female students Don't really make more money as well.
# 3. As the number of full-time employees increase, the median salary doesn't increase or decrease, it just remains neutral.

# %% [markdown]
# Now, let's create some common histograms to analyse the frequency distribution of different individual variables. I've experimented with the number of bins and the range of values for the x axis as per the information gathered when we used the `describe()` method.

# %%
recent_grads['Sample_size'].hist(bins=25, range=(0, 5000))

# %%
recent_grads['Median'].hist(bins=20)

# %%
recent_grads['Employed'].hist(bins=20, range=(0, 307900))

# %%
recent_grads['Full_time'].hist(bins=20)

# %%
recent_grads['ShareWomen'].hist(bins=5)

# %%
recent_grads['Unemployment_rate'].hist(bins=5)

# %%
recent_grads['Men'].hist(bins=20, range=(0, 173810))

# %%
recent_grads['Women'].hist(bins=20, range=(0, 370100))

# %% [markdown]
# Scatter matrices are a popular form of visualisation among data scientists when we want to compare relationships between variables and analyse their frequency distribution all on the same figure, in multiple subplots. We import it from the pandas.plotting module.

# %%
from pandas.plotting import scatter_matrix

scatter_matrix(recent_grads[['Sample_size', 'Median']])
plt.show()

# %%
(scatter_matrix(
    recent_grads[
    ['Sample_size', 'Median', 'Unemployment_rate']
]
))

plt.show()

# %% [markdown]
# Bar graphs are used to calculate the distribution of values for individual datapoints. It's useful when we want to compare variables, or to track changes over time. Here, we can look at the distribution between the number of women as shares of a total.

# %%
recent_grads[:10]['ShareWomen'].plot(kind='bar')

# %%
recent_grads.tail(10)['ShareWomen'].plot(kind='bar')

# %% [markdown]
# And over here, we can look at the individual distributions for the unemployment rate.

# %%
recent_grads.head(10)['Unemployment_rate'].plot(kind='bar')

# %%
recent_grads.tail(10)['Unemployment_rate'].plot(kind='bar')

# %% [markdown]
# Alright, that does it for this project. Thank you so much for reading through it.
